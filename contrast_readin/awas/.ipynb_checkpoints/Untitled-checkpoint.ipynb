# %%
import xarray as xr

# %%
mypath = '/mnt/home/sofia/TTS/contrast_merge_data/AWAS/awas_trace_gases.nc'
test = xr.open_dataset(mypath)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/software/anaconda3/envs/py3/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     194             try:
# --> 195                 file = self._cache[self._key]
#     196             except KeyError:
#
# ~/software/anaconda3/envs/py3/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      42         with self._lock:
# ---> 43             value = self._cache[key]
#      44             self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x7fc45d9ee440>, ('/mnt/home/sofia/TTS/contrast_merge_data/AWAS/awas_trace_gases.nc',), 'r', (('mmap', None), ('version', 2))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ...
