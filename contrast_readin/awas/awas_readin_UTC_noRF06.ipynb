# %%
# script to read in awas data for flights 5 - 14
# remove samples in SH, near guam, and where tracer values < 0

# %%
import xarray as xr
import numpy as np 
from matplotlib import pyplot as plt
import pandas as pd

# %%
### ---------------------- READ IN DATA  ---------------------- ###
# path to data
mypath = '/Volumes/scdrive2/contrast_merge_data/contrast_awas_merge/*.nc'

# read in merge all flights 
contrast_init = xr.open_mfdataset(mypath, combine='by_coords')
# drop the variables without category metadata (no instrument)
contrast_init = contrast_init.drop('DOAS_BrO').drop('DOAS_delta_BrO')

# change coordinate from "Time" to "Time_UTC"
contrast_init.coords['Time_UTC'] = (contrast_init.Time_UTC)

# %%
contrast_init
# Out:
# <xarray.Dataset>
# Dimensions:                           (Time: 597)
# Coordinates:
#   * Time                              (Time) datetime64[ns] 2014-01-22T00:20:25 ... 2014-02-25T07:17:05
#     Time_UTC                          (Time) datetime64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
# Data variables:
#     FLT_HH                            (Time) timedelta64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#     FLT_MM                            (Time) timedelta64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#     FLT_SS                            (Time) timedelta64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#     UTC_HH                            (Time) timedelta64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#     UTC_MM                            (Time) timedelta64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#     UTC_SS                            (Time) timedelta64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#     GALT_A                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGALT                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGEOIDHT                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGLAT                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGLON                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGQUAL                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGSPD                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PITCH                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     RICE                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ROLL                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     THDG                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     VISBC                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     VISTC                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ATX                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CONCD_RWOO                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CONCU100_RWOI                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CONCU500_RWOI                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CONCU_RWOI                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CONCV_VXL                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DBARD_RWOO                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DBARU_RWOI                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DPXC                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DP_DPL                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DP_DPR                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DP_VXL                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     EW_DPL                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     EW_DPR                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     EW_VXL                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     LATC                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     LONC                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MR                                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PALT                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PALTF                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PLWCC                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PLWCD_RWOO                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PSXC                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     RHODT                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     RHUM                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     SOLAZ                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     SOLDE                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     SOLEL                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     SOLZE                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     TASX                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     THETA                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     THETAE                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     THETAQ                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     THETAV                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     TVIR                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     UIC                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     VIC                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     VMR_VXL                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     WDC                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     WIC                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     WSC                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Profile_Number                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Profile_Direction                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2H6_Ethane                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2H2_Ethyne                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C3H8_Propane                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C4H10_Isobutane                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C4H10_nButane                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C5H12_Isopentane                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C5H12_nPentane                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C5H8_Isoprene                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C6H6_Benzene                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     OCS_Carbonyl_sulfide              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2H6S_Dimethyl_sulfide            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CCl2F2_CFC_12                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CCl3F_CFC_11                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CCl2FCCl2F_CFC112                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CCl3CClF2_CFC_112a                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2Cl3F3_CFC_113                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2Cl2F4_CFC_114                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHClF2_HCFC_22                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CClF2_HCFC_142b                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CCl2F_HCFC_141b                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2FCF3_HFC_134a                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C4H5F5_HFC365mfc                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3Cl_Methyl_chloride             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3Br_Methyl_bromide              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3I_Methyl_iodide                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2Cl2_Methylene_chloride         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHCl3_Chloroform                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CCl3_Methyl_chloroform         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CCl4_Carbon_tetrachloride         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2H4Cl2_1_2_Dichloroethane        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2HCl3_Trichloroethylene          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2Cl4_Tetrachloroethylene         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C6H5Cl_Chlorobenzene              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CBrClF2_Halon_1211                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2Br2F4_Halon_2402                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2BrCl_Bromochloromethane        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2Br2_Methylene_bromide          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHBrCl2_Bromodichloromethane      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHBr2Cl_Dibromochloromethane      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHBr3_Bromoform                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3ONO2_Methyl_nitrate            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2H5ONO2_Ethyl_nitrate            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C3H7NO3_Isopropyl_nitrate         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C4H9NO3_2_Butyl_nitrate           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C4H9NO3_n_Butyl_nitrate           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C5H11NO3_3_pentyl_nitrate         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C5H11NO3_2_pentyl_nitrate         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CO                                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CO2                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Methane                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrO                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HOBr+Br2                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Br_key                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     N2O5                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     O3->O2+O(1D)                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO2->NO+O(3P)                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     H2O2->2OH                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     N2O5->NO3+NO2                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HNO2->OH+NO                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HNO3->OH+NO2                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HNO4->HO2+NO2                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2O->H+HCO                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2O->H2+CO                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CHO->CH3+HCO                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C2H5CHO->C2H5+HCO                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3OOH->CH3O+OH                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3ONO2->CH3O+NO2                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CH2ONO2->CH3CH2O+NO2           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CO(OONO2)[PAN]->CH3CO(OO)+NO2  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CO(OONO2)[PAN]->CH3CO(O)+NO3   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2=C(CH3)CHO->Products           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3COCH=CH2->Products             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3COCH3->CH3CO+CH3               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3COCH2CH3->CH3CO+CH2CH3         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHOCHO->HCO+HCO                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHOCHO->H2+2CO                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHOCHO->CH2O+CO                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3COCHO->CH3CO+HCO               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Cl2->Cl+Cl                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ClO->Cl+O(3P)                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ClNO2->Cl+NO2                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ClONO->Cl+NO2                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ClONO2->Cl+NO3                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     ClONO2->ClO+NO2                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Br2->Br+Br                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrO->Br+O                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HOBr->OH+Br                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrNO->Br+NO                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrONO->Br+NO2                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrONO->BrO+NO                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrNO2->Br+NO2                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrONO2->BrO+NO2                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrONO2->Br+NO3                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     BrCl->Br+Cl                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CHBr3->Products                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CH2CH2CHO->C3H7+HCO            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CH2CH2CHO->C2H4+CH2CHOH        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Br2O->Products                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HCHO                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO_pptv                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO2_pptv                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     XNO2_pptv                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     O3_ppbv                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO_precErr_pptv                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO_biasErr_pptv                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO2_precErr_pptv                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     NO2_biasErr_pptv                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     O3_precErr_ppbv                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     O3_biasErr_ppbv                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     C3H8                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH2O                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     OCS                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CFC12                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CFC114                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     HCN                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     i_Butane                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     n_Butane                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Methyl_Chloride                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Acetaldehyde                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     i_Butene_1_Butene                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Methyl_Bromide                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     i_Pentane                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     n_Pentane                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Methanol                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Ethanol                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Acrolein                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Isoprene                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Methyl_Iodide                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     DMS                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Bromoethane                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CFC11                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CFC113                            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Propanal                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Acetone                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     2_Methylpentane                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     3_Methylpentane                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     n_Hexane                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Dichloromethane                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     2_Propanol                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     CH3CN                             (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MethylNitrate                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     PAN                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MACR                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MVK                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     3_MethylFuran                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Butanal                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MEK                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Ethyl_Iodide                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MTBE                              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Chloroform                        (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Carbon_Tetrachloride              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Bromochloromethane                (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     EthylNitrate                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     I_PropylNitrate                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     MBO                               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Benzene                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     n_Heptane                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Pentanal                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     2_Pentanone                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     3_Pentanone                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Bromodichloromethane              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Dibromomethane                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Chloroiodomethane                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     tert_ButylNitrate                 (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     I_ButylNitrate                    (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     2_ButylNitrate_n_ButylNitrate     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     2_PentylNitrate_3_PentylNitrate   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Toluene                           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Ethylbenzene_m_p_Xylene           (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     o_Xylene                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Tetrachloroethylene               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Dibromochloromethane              (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Bromoiodomethane                  (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Chlorobenzene                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Bromoform                         (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Alpha_Pinene                      (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Camphene                          (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Beta_Pinene                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     d_Limonene_3_Carene               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Alpha_Terpinene                   (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Para_Cymene                       (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     1_2_4_Trimethylbenzene            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     1_3_5_Trimethylbenzene            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     1_2_3_Trimethylbenzene            (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     Diiodomethane                     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     1_3_Dichlorobenzene               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     1_2_Dichlorobenzene               (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
# Attributes:
#     Institution:                     NCAR Atmospheric Chemistry Observations ...
#     Address:                         P.O. Box 3000, Boulder, CO 80307-3000
#     Phone:                           (303) 497-8194
#     Author:                          Shawn Honomichl
#     Author_Email:                    shawnh@ucar.edu
#     Nomenclature_compliance_note:    Spaces removed from variable names when ...
#     Merged_NetCDF_Creation_Date:     Wed Aug 24 21:04:36 2016
#     Project_Name:                    CONTRAST
#     Aircraft_Type:                   GV
#     Aircraft_Tail:                   N677F
#     Flight:                          rf05
#     Flight_Date:                     01/22/2014
#     Data_Aligned_to:                 AWAS
#     time_coordinate:                 Time
#     Master_Time_Units:               Seconds
#     Approximate_Data_Time_Interval:  164.0
#     Data_Collection_Duration:        6.73 Hours
#     Time_Range:                      00:20:25-07:03:49
#     time_coverage_start:             2014-01-22T00:20:30 +0000
#     time_coverage_end:               2014-01-22T07:04:11 +0000
#     Included_Instrument_Data:        Aircraft_NC,PROFILES,AWAS,CO,CO2CH4,DOAS...
#     Aircraft_NC_Input_File:          CONTRASTrf05.nc
#     PROFILES_Input_File:             CONTRAST-PROFILES_GV_20140122_R1.ict
#     AWAS_Input_File:                 CONTRAST-AWAS_GV_20140122_R0.ict
#     CO_Input_File:                   CONTRAST-CO_GV_20140122_R1.ict
#     CO2CH4_Input_File:               CONTRAST-CO2CH4_GV_20140122_R1.ict
#     DOAS_Input_File:                 n/a
#     GTCIMS_Input_File:               CONTRAST-GTCIMS_GV_20140122_R2.ict
#     HARP_Input_File:                 CONTRAST-HARP_GV_20140122_R1.ict
#     ISAF_Input_File:                 CONTRAST-ISAF_GV_20140122_R0.ict
#     NONO2O3_Input_File:              CONTRAST-NONO2O3_GV_20140122_R3.ict
#     TOGA_Input_File:                 CONTRAST-TOGA_GV_20140122_R2.ict
#     latitude_coordinate:             LATC
#     longitude_coordinate:            LONC
#     zaxis_coordinate:                PSXC
#     geospatial_lat_min:              10.26621
#     geospatial_lat_max:              18.81527
#     geospatial_lon_min:              140.82967
#     geospatial_lon_max:              150.04382
#     geospatial_vertical_min:         34.01939
#     geospatial_vertical_max:         14078.02
#     geospatial_vertical_positive:    up
#     geospatial_vertical_units:       m
#     fill_values:                     -99999.0
#     Categories:                      AWAS,Aircraft_NC,CO,DOAS_[MISSING],GTCIM...
#     landmarks:                       19.746 -155.457 Hawaii,34.481 -118.043 D...

# %%
### --- what instruments do each data variable come from?
#for ii in contrast_init.data_vars:
#    print(contrast_init[ii].attrs['Category'])

### --- print each awas measured tracer 
for ii in contrast_init.data_vars:
    if contrast_init[ii].attrs['Category'] == 'AWAS':
        print(contrast_init[ii].long_name)
# Out:
# C2H6_Ethane
# C2H2_Ethyne
# C3H8_Propane
# C4H10_Isobutane
# C4H10_nButane
# C5H12_Isopentane
# C5H12_nPentane
# C5H8_Isoprene
# C6H6_Benzene
# OCS_Carbonyl_sulfide
# C2H6S_Dimethyl_sulfide
# CCl2F2_CFC_12
# CCl3F_CFC_11
# CCl2FCCl2F_CFC112
# CCl3CClF2_CFC_112a
# C2Cl3F3_CFC_113
# C2Cl2F4_CFC_114
# CHClF2_HCFC_22
# CH3CClF2_HCFC_142b
# CH3CCl2F_HCFC_141b
# CH2FCF3_HFC_134a
# C4H5F5_HFC365mfc
# CH3Cl_Methyl_chloride
# CH3Br_Methyl_bromide
# CH3I_Methyl_iodide
# CH2Cl2_Methylene_chloride
# CHCl3_Chloroform
# CH3CCl3_Methyl_chloroform
# CCl4_Carbon_tetrachloride
# C2H4Cl2_1_2_Dichloroethane
# C2HCl3_Trichloroethylene
# C2Cl4_Tetrachloroethylene
# C6H5Cl_Chlorobenzene
# CBrClF2_Halon_1211
# C2Br2F4_Halon_2402
# CH2BrCl_Bromochloromethane
# CH2Br2_Methylene_bromide
# CHBrCl2_Bromodichloromethane
# CHBr2Cl_Dibromochloromethane
# CHBr3_Bromoform
# CH3ONO2_Methyl_nitrate
# C2H5ONO2_Ethyl_nitrate
# C3H7NO3_Isopropyl_nitrate
# C4H9NO3_2_Butyl_nitrate
# C4H9NO3_n_Butyl_nitrate
# C5H11NO3_3_pentyl_nitrate
# C5H11NO3_2_pentyl_nitrate

# %%
### --- subset the data so that we only keep awas tracers that we want 
# empyt dataset to fill with awas data 
awas_init = xr.Dataset()
# fill with anything that has 'awas' as the category
for ii in contrast_init.data_vars:
    if contrast_init[ii].attrs['Category'] == 'AWAS':
        awas_init[ii] = contrast_init[ii]
        
### --- remove any AWAS tracers we dont use in TTS paper (40 awas total used)
awas_trc_prelim = awas_init.drop('C5H12_Isopentane').drop('C5H8_Isoprene'). \
    drop('CH3I_Methyl_iodide'). \
    drop('C2HCl3_Trichloroethylene').drop('CH3ONO2_Methyl_nitrate'). \
    drop('C5H11NO3_3_pentyl_nitrate').drop('C5H11NO3_2_pentyl_nitrate')
print(len(awas_trc_prelim))

### --- awas aircraft parameters and location 
awas_param_init = xr.merge([contrast_init.GGALT, contrast_init.GGLAT, contrast_init.GGLON])
                            #contrast_init.Time_UTC])
awas_param_init               
    #contrast_init.WIC, contrast_init.PALT, contrast_init.RHUM])
# Out:
# 40
# <xarray.Dataset>
# Dimensions:   (Time: 597)
# Coordinates:
#   * Time      (Time) datetime64[ns] 2014-01-22T00:20:25 ... 2014-02-25T07:17:05
#     Time_UTC  (Time) datetime64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
# Data variables:
#     GGALT     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGLAT     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>
#     GGLON     (Time) float32 dask.array<chunksize=(59,), meta=np.ndarray>

# %%
### ---------------------- CONFINE TO NH  ---------------------- ###

# take a look at where values for latitude lie - NH, SH, or nan
#southhem = np.where(awas_param_init.GGLAT.values < 0)
studyarea = np.where((awas_param_init.GGLAT.values > 0) & (awas_param_init.GGLAT.values < 25))
print(np.size(studyarea))
#nullinit = np.isnan(awas_param_init.GGLAT.values).sum()

# keep only NH values, rewrite to awas_param 
awas_param_noblcorr = xr.Dataset()
for ii in awas_param_init.data_vars:
    param = awas_param_init[ii]
    nh_only = param[studyarea].values 
    awas_param_noblcorr[ii] = nh_only
    
# select NH only for all tracers 
awas_trc_twp = xr.Dataset()
for ii in awas_trc_prelim.data_vars:
    trc = awas_trc_prelim[ii]
    nh_only = trc[studyarea]
    awas_trc_twp[ii] = nh_only
# Out:
# 497

# %%
### ---------------------- REMOVE NULL VALUES, < 0 VALUES ---------------------- ###
# ignore comparison to nan warnings (for where trc<0)
np.warnings.filterwarnings('ignore')

### null values (-777, -888), make = nan 
awas_trc_noblcorr = xr.Dataset()
for ii in awas_trc_twp.data_vars:
    trc = awas_trc_twp[ii]
    trc_vals = trc.values
    
    # -------- locations for fills
    llod = awas_trc_twp[ii].attrs['LLOD']
    ulod = awas_trc_twp[ii].attrs['ULOD']
    
    # -------- make those locations nan and save to variable 
    #trc_masked = trc.where((trc.values != llod) & (trc.values != ulod))
    trc_masked = np.ma.masked_where(trc_vals < 0, trc_vals)
    trc_masked = np.ma.masked_where(trc_vals == llod, trc_masked)
    trc_masked = np.ma.masked_where(trc_vals == ulod, trc_masked)
    trc.values = trc_masked 
    
    awas_trc_noblcorr[ii] = trc

# %%
### ---------------------- ADD LIFETIMES AS AN ATTRIBUTE ---------------------- ###
### --- add attribute to each (BL, tropo, and UT lifetimes)
# read in from xls file to make dataframe
mypath2 = '/Volumes/scdrive2/TTS_2020/contrast_readin/awas/awas_lifetimes_08042020.xlsx'
awas_lifetimes = pd.read_excel(mypath2)

# fill in lifetime attributes using that dataframe 
for ii in enumerate(awas_trc_noblcorr.data_vars):
    myind = ii[0]
    trc = ii[1]
    awas_trc_noblcorr[trc].attrs['BL_lifetime'] = awas_lifetimes['BL_tau'][myind]
    awas_trc_noblcorr[trc].attrs['UT_lifetime'] = awas_lifetimes['UT_tau'][myind]
    awas_trc_noblcorr[trc].attrs['TROPO_lifetime'] = awas_lifetimes['TROPO_tau'][myind]

# %%
### ---------------------- REMOVE BL SAMPLES NEAR GUAM ---------------------- ###
# ~111 km/degree lat and ~108 km/degree long
# so this is about 11 km around guam 
# https://www.johndcook.com/how_big_is_a_degree.html
guam_coord = [13.4, 144.8]
cut = 0.16
print((111*0.16), (108*0.16))
guam_lat_cuts = [guam_coord[0]-cut, guam_coord[0]+cut]
guam_lon_cuts = [guam_coord[1]-cut, guam_coord[1]+cut]

# get the regions near guam to mask out and altitudes (not BL)
null_lat = np.where((awas_param_noblcorr.GGLAT > guam_lat_cuts[0]) 
                    & (awas_param_noblcorr.GGLAT < guam_lat_cuts[1]))
null_lon = np.where((awas_param_noblcorr.GGLON > guam_lon_cuts[0]) 
                    & (awas_param_noblcorr.GGLON < guam_lon_cuts[1]))
null_alt = np.where((awas_param_noblcorr.GGALT < 4000))

# get intersection, index list to mask 
near_guam = np.intersect1d(null_lat, null_lon, null_alt)

# get the opposite of that index, NOT near guam 
#not_guam = np.arange(0, len(toga_param.GGALT.values), dtype = float)
#not_guam[near_guam]=np.nan

not_guam = np.arange(0, len(awas_param_noblcorr.GGALT.values))
not_guam = np.delete(not_guam, near_guam)
# Out:
# 17.76 17.28

# %%
# keep only non-guam values - AIRCRAFT PARAM 
awas_param = xr.Dataset()
for ii in awas_param_noblcorr.coords:
    param = awas_param_noblcorr[ii]
    param_noguam = param[not_guam].values 
    awas_param[ii] = param_noguam

# keep only non-guam values - TRACERS 
awas_trc = xr.Dataset()
for ii in awas_trc_noblcorr.data_vars:
    trc = awas_trc_noblcorr[ii]
    trc_noguam = trc[not_guam]
    awas_trc[ii] = trc_noguam

# %%
### ---------------------- ADD AC PARAMETERS AS COORDINATES ---------------------- ###
# ---- add parameters as coordinates 
for ii in awas_param.coords:
    my_coord = awas_param[ii]
    awas_trc.coords[ii] = my_coord

# %%
### ---------------------- SAVE ---------------------- ###
### pickle it! 
awas_trc.to_netcdf(path = '/Volumes/scdrive2/TTS_2020/contrast_readin/awas/awas_trace_gases_twp_noRF06.nc')
print ('finished saving tracers')
# Out:
# finished saving tracers

# %%
###########################################################################################
###########################################################################################
###########################################################################################

# %%
###########################################################################################
### ---------------------- REPLACE TRACERS WITH ZEROS ---------------------- ###
# duplicate 
awas_trc_replace = awas_trc

myvars = ['C2H6S_Dimethyl_sulfide', 'CHBr2Cl_Dibromochloromethane', 
          'C4H9NO3_2_Butyl_nitrate', 'C4H9NO3_n_Butyl_nitrate']
mylows = [0.1, 0.07, 0.02, 0.03]

# dms 
dms = awas_trc_replace.C2H6S_Dimethyl_sulfide.values
dms_zloc = np.argwhere(dms == 0)
dms_replace = dms
dms_replace[dms_zloc] = (mylows[0]*0.8)

awas_trc_replace.C2H6S_Dimethyl_sulfide.values = dms_replace

#dibromomethane 
dibrom = awas_trc_replace.CHBr2Cl_Dibromochloromethane.values
dibrom_zloc = np.argwhere(dibrom == 0)
dibrom_replace = dibrom
dibrom_replace[dibrom_zloc] = (mylows[1]*0.8)

awas_trc_replace.CHBr2Cl_Dibromochloromethane.values = dibrom_replace

# 2 butyl 
but2 = awas_trc_replace.C4H9NO3_2_Butyl_nitrate.values
but2_zloc = np.argwhere(but2 == 0)
but2_replace = but2
but2_replace[but2_zloc] = (mylows[2]*0.8)

awas_trc_replace.C4H9NO3_2_Butyl_nitrate.values = but2_replace

# n butyl 
butn = awas_trc_replace.C4H9NO3_n_Butyl_nitrate.values
butn_zloc = np.argwhere(butn == 0)
butn_replace = butn
butn_replace[butn_zloc] = (mylows[3]*0.8)

awas_trc_replace.C4H9NO3_n_Butyl_nitrate.values = butn_replace

# %%
### ---------------------- SAVE ---------------------- ###
### pickle it! 
awas_trc_replace.to_netcdf(path = '/Volumes/scdrive2/TTS_2020/contrast_readin/awas/awas_trace_gases_twp_replace_noRF06.nc')
print ('finished saving tracers')
# Out:
# finished saving tracers

# %%
### ---------------------- GET INFO ---------------------- ###
#### 
# C2H6S_Dimethyl_sulfide
# C4H9NO3_2_Butyl_nitrate
# CHBr2Cl_Dibromochloromethane
# C4H9NO3_n_Butyl_nitrate
myvars = ['C2H6S_Dimethyl_sulfide', 'C4H9NO3_2_Butyl_nitrate', 
           'CHBr2Cl_Dibromochloromethane', 'C4H9NO3_n_Butyl_nitrate']

for vv in myvars:
    print(vv)
    v = awas_trc[vv].values
    print(np.nanmean(v))
    len_total = len(np.ndarray.flatten(v))
    len_zero = len(np.ndarray.flatten(np.argwhere(v == 0)))
    len_nan = len(np.where(~np.isfinite(v))[0])
    print(len_total, len_zero, len_nan)

    zero_loc = np.argwhere(v == 0)
    var_nozero = v
    var_nozero[zero_loc] = np.nan
    var_vals = var_nozero[~np.isnan(var_nozero)]
    var_min = np.min(var_vals)
    print(var_min)
    var_replace = v
    var_replace[zero_loc] = (var_min*0.8)
    print(np.nanmean(var_replace))
# Out:
# C2H6S_Dimethyl_sulfide
# 3.7826903
# 495 0 153
# 0.08
# 3.7826903
# C4H9NO3_2_Butyl_nitrate
# 0.5822155
# 495 0 3
# 0.016
# 0.5822155
# CHBr2Cl_Dibromochloromethane
# 0.17682114
# 495 0 3
# 0.056
# 0.17682114
# C4H9NO3_n_Butyl_nitrate
# 0.7896065
# 495 0 2
# 0.024
# 0.7896065

# %%
awas_trc
# Out:
# <xarray.Dataset>
# Dimensions:                       (GGALT: 495, GGLAT: 495, GGLON: 495, Time: 495)
# Coordinates:
#   * Time                          (Time) datetime64[ns] 2014-01-22T00:20:25 ... 2014-02-25T07:17:05
#     Time_UTC                      (Time) datetime64[ns] dask.array<chunksize=(59,), meta=np.ndarray>
#   * GGALT                         (GGALT) float32 3846.6377 4106.623 ... 952.71
#   * GGLAT                         (GGLAT) float32 13.294079 ... 13.395386
#   * GGLON                         (GGLON) float32 145.20465 ... 144.60631
# Data variables:
#     C2H6_Ethane                   (Time) float32 447.0 436.0 ... 743.0 746.0
#     C2H2_Ethyne                   (Time) float32 81.0 60.0 52.0 ... 101.0 116.0
#     C3H8_Propane                  (Time) float32 31.0 29.0 26.0 ... 57.0 59.0
#     C4H10_Isobutane               (Time) float32 4.0 1.9 1.9 1.9 ... 2.8 3.1 3.1
#     C4H10_nButane                 (Time) float32 7.1 4.3 3.7 3.2 ... 4.4 4.0 5.3
#     C5H12_nPentane                (Time) float32 1.3 0.1 0.5 nan ... 0.2 nan 0.2
#     C6H6_Benzene                  (Time) float32 9.7 7.2 6.9 ... 18.8 19.3 22.5
#     OCS_Carbonyl_sulfide          (Time) float32 575.0 561.0 ... 570.0 567.0
#     C2H6S_Dimethyl_sulfide        (Time) float32 15.5 21.3 14.6 ... 0.3 3.3 11.4
#     CCl2F2_CFC_12                 (Time) float32 517.0 519.0 ... 524.0 522.0
#     CCl3F_CFC_11                  (Time) float32 235.0 233.0 ... 235.0 235.0
#     CCl2FCCl2F_CFC112             (Time) float32 0.44 0.47 0.44 ... 0.47 0.44
#     CCl3CClF2_CFC_112a            (Time) float32 0.09 0.08 0.09 ... 0.1 0.1 0.11
#     C2Cl3F3_CFC_113               (Time) float32 73.5 73.2 74.9 ... 73.6 73.2
#     C2Cl2F4_CFC_114               (Time) float32 15.6 15.6 16.2 ... 16.0 16.1
#     CHClF2_HCFC_22                (Time) float32 225.0 225.0 ... 237.0 235.0
#     CH3CClF2_HCFC_142b            (Time) float32 21.3 21.5 21.7 ... 22.2 22.0
#     CH3CCl2F_HCFC_141b            (Time) float32 23.9 23.5 24.2 ... 24.4 24.2
#     CH2FCF3_HFC_134a              (Time) float32 75.5 74.6 76.0 ... 80.1 78.1
#     C4H5F5_HFC365mfc              (Time) float32 1.19 1.14 1.24 ... 1.25 1.23
#     CH3Cl_Methyl_chloride         (Time) float32 552.0 553.0 ... 593.0 594.0
#     CH3Br_Methyl_bromide          (Time) float32 7.8 7.7 7.56 ... 7.72 7.51 7.51
#     CH2Cl2_Methylene_chloride     (Time) float32 43.95 42.71 ... 57.88 60.84
#     CHCl3_Chloroform              (Time) float32 8.52 8.18 8.47 ... 10.39 10.79
#     CH3CCl3_Methyl_chloroform     (Time) float32 4.33 4.16 4.3 ... 3.9 3.95 3.94
#     CCl4_Carbon_tetrachloride     (Time) float32 84.2 83.3 85.7 ... 83.6 83.0
#     C2H4Cl2_1_2_Dichloroethane    (Time) float32 10.89 10.31 ... 12.79 13.83
#     C2Cl4_Tetrachloroethylene     (Time) float32 0.93 0.9 0.98 ... 1.29 1.25
#     C6H5Cl_Chlorobenzene          (Time) float32 0.65 0.63 0.62 ... 0.7 0.73
#     CBrClF2_Halon_1211            (Time) float32 nan nan nan ... 3.61 3.61 3.63
#     C2Br2F4_Halon_2402            (Time) float32 0.43 0.42 0.43 ... 0.41 0.41
#     CH2BrCl_Bromochloromethane    (Time) float32 0.11 0.13 0.14 ... 0.2 0.2 0.19
#     CH2Br2_Methylene_bromide      (Time) float32 0.96 0.98 1.04 ... 0.99 0.95
#     CHBrCl2_Bromodichloromethane  (Time) float32 nan nan nan ... 0.28 0.28 0.34
#     CHBr2Cl_Dibromochloromethane  (Time) float32 0.32 0.38 0.52 ... 0.14 0.15
#     CHBr3_Bromoform               (Time) float32 0.77 0.76 0.8 ... 0.63 0.54
#     C2H5ONO2_Ethyl_nitrate        (Time) float32 4.2 4.36 4.08 ... 2.27 2.29
#     C3H7NO3_Isopropyl_nitrate     (Time) float32 1.94 1.78 1.8 ... 2.54 2.78
#     C4H9NO3_2_Butyl_nitrate       (Time) float32 1.11 0.91 1.07 ... 0.91 1.03
#     C4H9NO3_n_Butyl_nitrate       (Time) float32 0.024 0.024 0.024 ... 1.62 1.69
