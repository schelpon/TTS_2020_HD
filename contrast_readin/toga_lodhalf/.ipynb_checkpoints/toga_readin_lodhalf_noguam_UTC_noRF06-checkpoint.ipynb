# %%
# script to read in awas data for flights 5 - 14
# BL TREATMENT - remove samples that are within ~17 km of guam 
# date created: 2/14/2020
# author: sofia chelpon

# %%
import xarray as xr
import numpy as np 
from matplotlib import pyplot as plt
import pandas as pd

# %%
### ---------------------- READ IN DATA  ---------------------- ###
# path to data
mypath = '/Volumes/scdrive2/contrast_merge_data/contrast_toga_merge/*.nc'
# read in merge all flights 
contrast_init = xr.open_mfdataset(mypath, combine='by_coords')

# %%
# change coordinate from "Time" to "Time_UTC"
contrast_init.assign_coords({'Time': contrast_init.Time_UTC.values})
contrast_init.Time.values[640]
# Out:
# numpy.datetime64('2014-01-29T00:13:05.000000000')

# %%
### --- desired toga tracers
# empyt dataset to fill with toga data (12 total)
toga_trc_prelim = xr.merge([contrast_init.Acetaldehyde, contrast_init.n_Butane, 
                     contrast_init.i_Butane, contrast_init.Benzene, 
                     contrast_init.C3H8, contrast_init.Methanol,
                     contrast_init.Bromoform, contrast_init.Tetrachloroethylene,  
                     contrast_init.Dibromomethane,  contrast_init.Dichloromethane, 
                     contrast_init.Chloroform, contrast_init.Carbon_Tetrachloride])
print(len(toga_trc_prelim))

### --- aircraft parameters and location 
toga_param_init = xr.merge([contrast_init.GGALT, contrast_init.GGLAT, contrast_init.GGLON, 
                           contrast_init.Time_UTC])
                      #contrast_init.WIC, contrast_init.PALT, contrast_init.RHUM])
# Out:
# 12

# %%
studyarea = np.where((toga_param_init.GGLAT.values > 0) & (toga_param_init.GGLAT.values < 25))
# Out:
# /Users/schelpon/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# /Users/schelpon/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.

# %%
### ---------------------- CONFINE TO NH  ---------------------- ###
# find NH values, what we want 
studyarea = np.where((toga_param_init.GGLAT.values > 0) & (toga_param_init.GGLAT.values < 25))
print(np.size(studyarea))

# keep only NH values, rewrite to toga_param - AIRCRAFT PARAMETERS
toga_param_noblcorr = xr.Dataset()
for ii in toga_param_init.data_vars:
    param = toga_param_init[ii]
    nh_only = param[studyarea].values 
    toga_param_noblcorr[ii] = nh_only
toga_param_noblcorr

# select NH only for all - TRACERS 
toga_trc_twp_noreplace = xr.Dataset()
for ii in toga_trc_prelim.data_vars:
    trc = toga_trc_prelim[ii]
    nh_only = trc[studyarea]
    toga_trc_twp_noreplace[ii] = nh_only
# Out:
# 2177
# /Users/schelpon/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in greater
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/schelpon/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in less
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
### ---------------------- APPLY DETECTION LIMIT SUBSTITUTION TO TRC ---------------------- ###
# make attribute for detection level 
toga_lods = [5, 0.5, 0.5, 1, 10, 20, 0.1, 0.3, 0.03, 1, 1, 1];

for ii in enumerate(toga_trc_twp_noreplace.data_vars):
    myind = ii[0]
    trc = ii[1]
    toga_trc_twp_noreplace[trc].attrs['LOD'] = toga_lods[myind]

### --- replace all LLOD/ULOD (-888, -777) with 1/2 the LOD for each tracer 
toga_trc_pre_blcorr = xr.Dataset()    
for ii in toga_trc_twp_noreplace.data_vars:
    # get this tracer and its LOD 
    trc_vals = toga_trc_twp_noreplace[ii].values
    trc = toga_trc_twp_noreplace[ii]
    
    # -------- locations for fills
    # llod 
    llod = trc.attrs['LLOD']
    where_llod = np.where(trc_vals == llod)
    # ulod 
    ulod = trc.attrs['ULOD']
    where_ulod = np.where(trc_vals == ulod)
    
    # -------- make those locations equal to LOD/2 
    trc_vals[where_llod] = trc.LOD/2
    trc_vals[where_ulod] = trc.LOD/2
    # replace values in Dataarray with that including substituded values, save to var 
    trc.values = trc_vals
    toga_trc_pre_blcorr[ii] = trc
    print(np.nanmax(toga_trc_pre_blcorr[ii]))
# Out:
# 4121.9
# 400.13
# 156.94
# 116.38
# 390.0
# 4712.0
# 1.652
# 2.7
# 1.742
# 93.0
# 16.94
# 102.0

# %%
### ---------------------- ADD LIFETIMES AS AN ATTRIBUTE ---------------------- ###
# read in from xls file to make dataframe
mypath2 = '/Volumes/scdrive2/TTS_2020/contrast_readin/toga_lodhalf/toga_lifetimes_08042020.xlsx'
toga_lifetimes = pd.read_excel(mypath2)

# add attribute to each tracer 
for ii in enumerate(toga_trc_pre_blcorr.data_vars):
    myind = ii[0]
    trc = ii[1]
    toga_trc_pre_blcorr[trc].attrs['BL_lifetime'] = toga_lifetimes['BL_tau'][myind]
    toga_trc_pre_blcorr[trc].attrs['UT_lifetime'] = toga_lifetimes['UT_tau'][myind]
    toga_trc_pre_blcorr[trc].attrs['TROPO_lifetime'] = toga_lifetimes['TROPO_tau'][myind]

# %%
toga_trc_pre_blcorr
# Out:
# <xarray.Dataset>
# Dimensions:               (Time: 2177)
# Coordinates:
#   * Time                  (Time) datetime64[ns] 2014-01-17T00:16:06 ... 2014-02-25T07:22:04
# Data variables:
#     Acetaldehyde          (Time) float32 286.7 191.2 126.8 ... 278.9 305.6 454.0
#     n_Butane              (Time) float32 3.96 1.51 1.68 ... 7.69 31.98 400.13
#     i_Butane              (Time) float32 2.99 2.49 2.6 ... 5.17 15.43 156.94
#     Benzene               (Time) float32 nan nan nan 7.28 ... 19.92 24.05 56.01
#     C3H8                  (Time) float32 54.0 41.0 13.0 18.0 ... 69.0 79.0 154.0
#     Methanol              (Time) float32 829.0 611.0 378.0 ... 1032.0 1413.0
#     Bromoform             (Time) float32 nan 0.689 0.48 ... 0.638 0.664 0.681
#     Tetrachloroethylene   (Time) float32 nan 0.15 0.15 0.15 ... 1.31 1.23 2.2
#     Dibromomethane        (Time) float32 nan nan nan nan ... 0.87 0.85 0.936
#     Dichloromethane       (Time) float32 46.24 44.49 50.11 ... 59.04 59.33 62.0
#     Chloroform            (Time) float32 10.8 9.39 10.29 ... 10.6 10.96 12.31
#     Carbon_Tetrachloride  (Time) float32 96.0 97.1 94.3 96.7 ... 81.0 80.9 77.2

# %%
### ---------------------- REMOVE BL SAMPLES NEAR GUAM ---------------------- ###
# ~111 km/degree lat and ~108 km/degree long
# so this is about 11 km around guam 
# https://www.johndcook.com/how_big_is_a_degree.html
guam_coord = [13.4, 144.8]
cut = 0.16
print((111*0.16), (108*0.16))
guam_lat_cuts = [guam_coord[0]-cut, guam_coord[0]+cut]
guam_lon_cuts = [guam_coord[1]-cut, guam_coord[1]+cut]

# get the regions near guam to mask out and altitudes (not BL)
null_lat = np.where((toga_param_noblcorr.GGLAT > guam_lat_cuts[0]) 
                    & (toga_param_noblcorr.GGLAT < guam_lat_cuts[1]))
null_lon = np.where((toga_param_noblcorr.GGLON > guam_lon_cuts[0]) 
                    & (toga_param_noblcorr.GGLON < guam_lon_cuts[1]))
null_alt = np.where((toga_param_noblcorr.GGALT < 4000))

# get intersection, index list to mask 
near_guam = np.intersect1d(null_lat, null_lon, null_alt)

# get the opposite of that index, NOT near guam 
#not_guam = np.arange(0, len(toga_param.GGALT.values), dtype = float)
#not_guam[near_guam]=np.nan

not_guam = np.arange(0, len(toga_param_noblcorr.GGALT.values))
not_guam = np.delete(not_guam, near_guam)
# Out:
# 17.76 17.28

# %%
# keep only non-guam values - AIRCRAFT PARAM 
toga_param = xr.Dataset()
for ii in toga_param_noblcorr.coords:
    param = toga_param_noblcorr[ii]
    param_noguam = param[not_guam].values 
    toga_param[ii] = param_noguam

# keep only non-guam values - TRACERS 
toga_trc = xr.Dataset()
for ii in toga_trc_pre_blcorr.data_vars:
    trc = toga_trc_pre_blcorr[ii]
    trc_noguam = trc[not_guam]
    toga_trc[ii] = trc_noguam
    print(np.nanmax(toga_trc[ii]))
# Out:
# 537.8
# 66.82
# 44.98
# 69.85
# 356.0
# 1233.0
# 1.638
# 2.7
# 1.742
# 93.0
# 16.94
# 102.0

# %%
### ---------------------- ADD AC PARAMETERS AS COORDINATES ---------------------- ###
for ii in toga_param.coords:
    my_coord = toga_param[ii]
    toga_trc.coords[ii] = my_coord

# %%
big = np.where(toga_trc.Acetaldehyde.values > 1000)
plt.plot(toga_trc.Acetaldehyde)
print(toga_trc.GGALT[big], toga_trc.GGLAT[big], toga_trc.GGLON[big])

toga_trc
# Out:
# <xarray.DataArray 'GGALT' (GGALT: 0)>
# array([], dtype=float32)
# Coordinates:
#   * GGALT    (GGALT) float32  <xarray.DataArray 'GGLAT' (GGLAT: 0)>
# array([], dtype=float32)
# Coordinates:
#   * GGLAT    (GGLAT) float32  <xarray.DataArray 'GGLON' (GGLON: 0)>
# array([], dtype=float32)
# Coordinates:
#   * GGLON    (GGLON) float32
# /Users/schelpon/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# <xarray.Dataset>
# Dimensions:               (GGALT: 2120, GGLAT: 2120, GGLON: 2120, Time: 2120, Time_UTC: 2120)
# Coordinates:
#   * Time                  (Time) datetime64[ns] 2014-01-17T00:18:06 ... 2014-02-25T07:18:04
#   * GGALT                 (GGALT) float32 3127.166 4212.603 ... 957.75916
#   * GGLAT                 (GGLAT) float32 13.379817 13.258845 ... 13.409988
#   * GGLON                 (GGLON) float32 144.9935 145.1362 ... 144.63826
#   * Time_UTC              (Time_UTC) datetime64[ns] 2014-01-17T00:18:24 ... 2014-02-25T07:18:22
# Data variables:
#     Acetaldehyde          (Time) float32 191.2 126.8 nan ... 233.3 323.8 278.9
#     n_Butane              (Time) float32 1.51 1.68 1.42 1.14 ... 2.79 3.55 7.69
#     i_Butane              (Time) float32 2.49 2.6 2.17 1.09 ... 2.47 3.29 5.17
#     Benzene               (Time) float32 nan nan 7.28 8.23 ... 14.91 17.39 19.92
#     C3H8                  (Time) float32 41.0 13.0 18.0 5.0 ... 60.0 75.0 69.0
#     Methanol              (Time) float32 611.0 378.0 228.0 ... 931.0 905.0 959.0
#     Bromoform             (Time) float32 0.689 0.48 0.05 ... 0.644 0.561 0.638
#     Tetrachloroethylene   (Time) float32 0.15 0.15 0.15 0.15 ... 1.06 1.28 1.31
#     Dibromomethane        (Time) float32 nan nan nan 1.043 ... 0.927 0.89 0.87
#     Dichloromethane       (Time) float32 44.49 50.11 42.03 ... 51.22 55.55 59.04
#     Chloroform            (Time) float32 9.39 10.29 8.67 ... 10.22 10.87 10.6
#     Carbon_Tetrachloride  (Time) float32 97.1 94.3 96.7 94.6 ... 77.1 79.1 81.0

# %%
### pickle it! 
toga_trc.to_netcdf(path = '/Volumes/scdrive2/TTS_2020/contrast_readin/toga_lodhalf/toga_trace_gases_twp_noRF06.nc')
print ('finished saving tracers')
# Out:
# finished saving tracers

# %%
toga_trc
# Out:
# <xarray.Dataset>
# Dimensions:               (GGALT: 2120, GGLAT: 2120, GGLON: 2120, Time: 2120, Time_UTC: 2120)
# Coordinates:
#   * Time                  (Time) datetime64[ns] 2014-01-17T00:18:06 ... 2014-02-25T07:18:04
#   * GGALT                 (GGALT) float32 3127.166 4212.603 ... 957.75916
#   * GGLAT                 (GGLAT) float32 13.379817 13.258845 ... 13.409988
#   * GGLON                 (GGLON) float32 144.9935 145.1362 ... 144.63826
#   * Time_UTC              (Time_UTC) datetime64[ns] 2014-01-17T00:18:24 ... 2014-02-25T07:18:22
# Data variables:
#     Acetaldehyde          (Time) float32 191.2 126.8 nan ... 233.3 323.8 278.9
#     n_Butane              (Time) float32 1.51 1.68 1.42 1.14 ... 2.79 3.55 7.69
#     i_Butane              (Time) float32 2.49 2.6 2.17 1.09 ... 2.47 3.29 5.17
#     Benzene               (Time) float32 nan nan 7.28 8.23 ... 14.91 17.39 19.92
#     C3H8                  (Time) float32 41.0 13.0 18.0 5.0 ... 60.0 75.0 69.0
#     Methanol              (Time) float32 611.0 378.0 228.0 ... 931.0 905.0 959.0
#     Bromoform             (Time) float32 0.689 0.48 0.05 ... 0.644 0.561 0.638
#     Tetrachloroethylene   (Time) float32 0.15 0.15 0.15 0.15 ... 1.06 1.28 1.31
#     Dibromomethane        (Time) float32 nan nan nan 1.043 ... 0.927 0.89 0.87
#     Dichloromethane       (Time) float32 44.49 50.11 42.03 ... 51.22 55.55 59.04
#     Chloroform            (Time) float32 9.39 10.29 8.67 ... 10.22 10.87 10.6
#     Carbon_Tetrachloride  (Time) float32 97.1 94.3 96.7 94.6 ... 77.1 79.1 81.0

# %%
mypath = '/Volumes/scdrive2/contrast_merge_data/contrast_toga_merge/CONTRAST-TOGA-MERGE_GV_20140224_R1_rf15.nc'
contrast_init = xr.open_dataset(mypath)
contrast_init
# Out:
# <xarray.Dataset>
# Dimensions:                           (Time: 227)
# Coordinates:
#   * Time                              (Time) datetime64[ns] 2014-02-24T23:04:05 ... 2014-02-25T07:22:04
# Data variables:
#     Time_UTC                          (Time) datetime64[ns] ...
#     FLT_HH                            (Time) timedelta64[ns] ...
#     FLT_MM                            (Time) timedelta64[ns] ...
#     FLT_SS                            (Time) timedelta64[ns] ...
#     UTC_HH                            (Time) timedelta64[ns] ...
#     UTC_MM                            (Time) timedelta64[ns] ...
#     UTC_SS                            (Time) timedelta64[ns] ...
#     GALT_A                            (Time) float32 ...
#     GGALT                             (Time) float32 ...
#     GGEOIDHT                          (Time) float32 ...
#     GGLAT                             (Time) float32 ...
#     GGLON                             (Time) float32 ...
#     GGQUAL                            (Time) float32 ...
#     GGSPD                             (Time) float32 ...
#     PITCH                             (Time) float32 ...
#     RICE                              (Time) float32 ...
#     ROLL                              (Time) float32 ...
#     THDG                              (Time) float32 ...
#     VISBC                             (Time) float32 ...
#     VISTC                             (Time) float32 ...
#     ATX                               (Time) float32 ...
#     CONCD_RWOO                        (Time) float32 ...
#     CONCU100_RWOI                     (Time) float32 ...
#     CONCU500_RWOI                     (Time) float32 ...
#     CONCU_RWOI                        (Time) float32 ...
#     CONCV_VXL                         (Time) float32 ...
#     DBARD_RWOO                        (Time) float32 ...
#     DBARU_RWOI                        (Time) float32 ...
#     DPXC                              (Time) float32 ...
#     DP_DPL                            (Time) float32 ...
#     DP_DPR                            (Time) float32 ...
#     DP_VXL                            (Time) float32 ...
#     EW_DPL                            (Time) float32 ...
#     EW_DPR                            (Time) float32 ...
#     EW_VXL                            (Time) float32 ...
#     LATC                              (Time) float32 ...
#     LONC                              (Time) float32 ...
#     MR                                (Time) float32 ...
#     PALT                              (Time) float32 ...
#     PALTF                             (Time) float32 ...
#     PLWCC                             (Time) float32 ...
#     PLWCD_RWOO                        (Time) float32 ...
#     PSXC                              (Time) float32 ...
#     RHODT                             (Time) float32 ...
#     RHUM                              (Time) float32 ...
#     SOLAZ                             (Time) float32 ...
#     SOLDE                             (Time) float32 ...
#     SOLEL                             (Time) float32 ...
#     SOLZE                             (Time) float32 ...
#     TASX                              (Time) float32 ...
#     THETA                             (Time) float32 ...
#     THETAE                            (Time) float32 ...
#     THETAQ                            (Time) float32 ...
#     THETAV                            (Time) float32 ...
#     TVIR                              (Time) float32 ...
#     UIC                               (Time) float32 ...
#     VIC                               (Time) float32 ...
#     VMR_VXL                           (Time) float32 ...
#     WDC                               (Time) float32 ...
#     WIC                               (Time) float32 ...
#     WSC                               (Time) float32 ...
#     Profile_Number                    (Time) float32 ...
#     Profile_Direction                 (Time) float32 ...
#     C2H6_Ethane                       (Time) float32 ...
#     C2H2_Ethyne                       (Time) float32 ...
#     C3H8_Propane                      (Time) float32 ...
#     C4H10_Isobutane                   (Time) float32 ...
#     C4H10_nButane                     (Time) float32 ...
#     C5H12_Isopentane                  (Time) float32 ...
#     C5H12_nPentane                    (Time) float32 ...
#     C5H8_Isoprene                     (Time) float32 ...
#     C6H6_Benzene                      (Time) float32 ...
#     OCS_Carbonyl_sulfide              (Time) float32 ...
#     C2H6S_Dimethyl_sulfide            (Time) float32 ...
#     CCl2F2_CFC_12                     (Time) float32 ...
#     CCl3F_CFC_11                      (Time) float32 ...
#     CCl2FCCl2F_CFC112                 (Time) float32 ...
#     CCl3CClF2_CFC_112a                (Time) float32 ...
#     C2Cl3F3_CFC_113                   (Time) float32 ...
#     C2Cl2F4_CFC_114                   (Time) float32 ...
#     CHClF2_HCFC_22                    (Time) float32 ...
#     CH3CClF2_HCFC_142b                (Time) float32 ...
#     CH3CCl2F_HCFC_141b                (Time) float32 ...
#     CH2FCF3_HFC_134a                  (Time) float32 ...
#     C4H5F5_HFC365mfc                  (Time) float32 ...
#     CH3Cl_Methyl_chloride             (Time) float32 ...
#     CH3Br_Methyl_bromide              (Time) float32 ...
#     CH3I_Methyl_iodide                (Time) float32 ...
#     CH2Cl2_Methylene_chloride         (Time) float32 ...
#     CHCl3_Chloroform                  (Time) float32 ...
#     CH3CCl3_Methyl_chloroform         (Time) float32 ...
#     CCl4_Carbon_tetrachloride         (Time) float32 ...
#     C2H4Cl2_1_2_Dichloroethane        (Time) float32 ...
#     C2HCl3_Trichloroethylene          (Time) float32 ...
#     C2Cl4_Tetrachloroethylene         (Time) float32 ...
#     C6H5Cl_Chlorobenzene              (Time) float32 ...
#     CBrClF2_Halon_1211                (Time) float32 ...
#     C2Br2F4_Halon_2402                (Time) float32 ...
#     CH2BrCl_Bromochloromethane        (Time) float32 ...
#     CH2Br2_Methylene_bromide          (Time) float32 ...
#     CHBrCl2_Bromodichloromethane      (Time) float32 ...
#     CHBr2Cl_Dibromochloromethane      (Time) float32 ...
#     CHBr3_Bromoform                   (Time) float32 ...
#     CH3ONO2_Methyl_nitrate            (Time) float32 ...
#     C2H5ONO2_Ethyl_nitrate            (Time) float32 ...
#     C3H7NO3_Isopropyl_nitrate         (Time) float32 ...
#     C4H9NO3_2_Butyl_nitrate           (Time) float32 ...
#     C4H9NO3_n_Butyl_nitrate           (Time) float32 ...
#     C5H11NO3_3_pentyl_nitrate         (Time) float32 ...
#     C5H11NO3_2_pentyl_nitrate         (Time) float32 ...
#     CO                                (Time) float32 ...
#     CO2                               (Time) float32 ...
#     Methane                           (Time) float32 ...
#     DOAS_BrO                          (Time) float32 ...
#     DOAS_delta_BrO                    (Time) float32 ...
#     BrO                               (Time) float32 ...
#     HOBr+Br2                          (Time) float32 ...
#     Br_key                            (Time) float32 ...
#     N2O5                              (Time) float32 ...
#     O3->O2+O(1D)                      (Time) float32 ...
#     NO2->NO+O(3P)                     (Time) float32 ...
#     H2O2->2OH                         (Time) float32 ...
#     N2O5->NO3+NO2                     (Time) float32 ...
#     HNO2->OH+NO                       (Time) float32 ...
#     HNO3->OH+NO2                      (Time) float32 ...
#     HNO4->HO2+NO2                     (Time) float32 ...
#     CH2O->H+HCO                       (Time) float32 ...
#     CH2O->H2+CO                       (Time) float32 ...
#     CH3CHO->CH3+HCO                   (Time) float32 ...
#     C2H5CHO->C2H5+HCO                 (Time) float32 ...
#     CH3OOH->CH3O+OH                   (Time) float32 ...
#     CH3ONO2->CH3O+NO2                 (Time) float32 ...
#     CH3CH2ONO2->CH3CH2O+NO2           (Time) float32 ...
#     CH3CO(OONO2)[PAN]->CH3CO(OO)+NO2  (Time) float32 ...
#     CH3CO(OONO2)[PAN]->CH3CO(O)+NO3   (Time) float32 ...
#     CH2=C(CH3)CHO->Products           (Time) float32 ...
#     CH3COCH=CH2->Products             (Time) float32 ...
#     CH3COCH3->CH3CO+CH3               (Time) float32 ...
#     CH3COCH2CH3->CH3CO+CH2CH3         (Time) float32 ...
#     CHOCHO->HCO+HCO                   (Time) float32 ...
#     CHOCHO->H2+2CO                    (Time) float32 ...
#     CHOCHO->CH2O+CO                   (Time) float32 ...
#     CH3COCHO->CH3CO+HCO               (Time) float32 ...
#     Cl2->Cl+Cl                        (Time) float32 ...
#     ClO->Cl+O(3P)                     (Time) float32 ...
#     ClNO2->Cl+NO2                     (Time) float32 ...
#     ClONO->Cl+NO2                     (Time) float32 ...
#     ClONO2->Cl+NO3                    (Time) float32 ...
#     ClONO2->ClO+NO2                   (Time) float32 ...
#     Br2->Br+Br                        (Time) float32 ...
#     BrO->Br+O                         (Time) float32 ...
#     HOBr->OH+Br                       (Time) float32 ...
#     BrNO->Br+NO                       (Time) float32 ...
#     BrONO->Br+NO2                     (Time) float32 ...
#     BrONO->BrO+NO                     (Time) float32 ...
#     BrNO2->Br+NO2                     (Time) float32 ...
#     BrONO2->BrO+NO2                   (Time) float32 ...
#     BrONO2->Br+NO3                    (Time) float32 ...
#     BrCl->Br+Cl                       (Time) float32 ...
#     CHBr3->Products                   (Time) float32 ...
#     CH3CH2CH2CHO->C3H7+HCO            (Time) float32 ...
#     CH3CH2CH2CHO->C2H4+CH2CHOH        (Time) float32 ...
#     Br2O->Products                    (Time) float32 ...
#     HCHO                              (Time) float32 ...
#     NO_pptv                           (Time) float32 ...
#     NO2_pptv                          (Time) float32 ...
#     XNO2_pptv                         (Time) float32 ...
#     O3_ppbv                           (Time) float32 ...
#     NO_precErr_pptv                   (Time) float32 ...
#     NO_biasErr_pptv                   (Time) float32 ...
#     NO2_precErr_pptv                  (Time) float32 ...
#     NO2_biasErr_pptv                  (Time) float32 ...
#     O3_precErr_ppbv                   (Time) float32 ...
#     O3_biasErr_ppbv                   (Time) float32 ...
#     C3H8                              (Time) float32 ...
#     CH2O                              (Time) float32 ...
#     OCS                               (Time) float32 ...
#     CFC12                             (Time) float32 ...
#     CFC114                            (Time) float32 ...
#     HCN                               (Time) float32 ...
#     i_Butane                          (Time) float32 ...
#     n_Butane                          (Time) float32 ...
#     Methyl_Chloride                   (Time) float32 ...
#     Acetaldehyde                      (Time) float32 ...
#     i_Butene_1_Butene                 (Time) float32 ...
#     Methyl_Bromide                    (Time) float32 ...
#     i_Pentane                         (Time) float32 ...
#     n_Pentane                         (Time) float32 ...
#     Methanol                          (Time) float32 ...
#     Ethanol                           (Time) float32 ...
#     Acrolein                          (Time) float32 ...
#     Isoprene                          (Time) float32 ...
#     Methyl_Iodide                     (Time) float32 ...
#     DMS                               (Time) float32 ...
#     Bromoethane                       (Time) float32 ...
#     CFC11                             (Time) float32 ...
#     CFC113                            (Time) float32 ...
#     Propanal                          (Time) float32 ...
#     Acetone                           (Time) float32 ...
#     2_Methylpentane                   (Time) float32 ...
#     3_Methylpentane                   (Time) float32 ...
#     n_Hexane                          (Time) float32 ...
#     Dichloromethane                   (Time) float32 ...
#     2_Propanol                        (Time) float32 ...
#     CH3CN                             (Time) float32 ...
#     MethylNitrate                     (Time) float32 ...
#     PAN                               (Time) float32 ...
#     MACR                              (Time) float32 ...
#     MVK                               (Time) float32 ...
#     3_MethylFuran                     (Time) float32 ...
#     Butanal                           (Time) float32 ...
#     MEK                               (Time) float32 ...
#     Ethyl_Iodide                      (Time) float32 ...
#     MTBE                              (Time) float32 ...
#     Chloroform                        (Time) float32 ...
#     Carbon_Tetrachloride              (Time) float32 ...
#     Bromochloromethane                (Time) float32 ...
#     EthylNitrate                      (Time) float32 ...
#     I_PropylNitrate                   (Time) float32 ...
#     MBO                               (Time) float32 ...
#     Benzene                           (Time) float32 ...
#     n_Heptane                         (Time) float32 ...
#     Pentanal                          (Time) float32 ...
#     2_Pentanone                       (Time) float32 ...
#     3_Pentanone                       (Time) float32 ...
#     Bromodichloromethane              (Time) float32 ...
#     Dibromomethane                    (Time) float32 ...
#     Chloroiodomethane                 (Time) float32 ...
#     tert_ButylNitrate                 (Time) float32 ...
#     I_ButylNitrate                    (Time) float32 ...
#     2_ButylNitrate_n_ButylNitrate     (Time) float32 ...
#     2_PentylNitrate_3_PentylNitrate   (Time) float32 ...
#     Toluene                           (Time) float32 ...
#     Ethylbenzene_m_p_Xylene           (Time) float32 ...
#     o_Xylene                          (Time) float32 ...
#     Tetrachloroethylene               (Time) float32 ...
#     Dibromochloromethane              (Time) float32 ...
#     Bromoiodomethane                  (Time) float32 ...
#     Chlorobenzene                     (Time) float32 ...
#     Bromoform                         (Time) float32 ...
#     Alpha_Pinene                      (Time) float32 ...
#     Camphene                          (Time) float32 ...
#     Beta_Pinene                       (Time) float32 ...
#     d_Limonene_3_Carene               (Time) float32 ...
#     Alpha_Terpinene                   (Time) float32 ...
#     Para_Cymene                       (Time) float32 ...
#     1_2_4_Trimethylbenzene            (Time) float32 ...
#     1_3_5_Trimethylbenzene            (Time) float32 ...
#     1_2_3_Trimethylbenzene            (Time) float32 ...
#     Diiodomethane                     (Time) float32 ...
#     1_3_Dichlorobenzene               (Time) float32 ...
#     1_2_Dichlorobenzene               (Time) float32 ...
# Attributes:
#     Institution:                     NCAR Atmospheric Chemistry Observations ...
#     Address:                         P.O. Box 3000, Boulder, CO 80307-3000
#     Phone:                           (303) 497-8194
#     Author:                          Shawn Honomichl
#     Author_Email:                    shawnh@ucar.edu
#     Nomenclature_compliance_note:    Spaces removed from variable names when ...
#     Merged_NetCDF_Creation_Date:     Wed Aug 24 21:13:40 2016
#     Project_Name:                    CONTRAST
#     Aircraft_Type:                   GV
#     Aircraft_Tail:                   N677F
#     Flight:                          rf15
#     Flight_Date:                     02/24/2014
#     Data_Aligned_to:                 TOGA
#     time_coordinate:                 Time
#     Master_Time_Units:               Seconds
#     Approximate_Data_Time_Interval:  120.0
#     Data_Collection_Duration:        8.30 Hours
#     Time_Range:                      23:04:05-07:22:04
#     time_coverage_start:             2014-02-24T23:04:23 +0000
#     time_coverage_end:               2014-02-25T07:22:22 +0000
#     Included_Instrument_Data:        Aircraft_NC,PROFILES,AWAS,CO,CO2CH4,DOAS...
#     Aircraft_NC_Input_File:          CONTRASTrf15.nc
#     PROFILES_Input_File:             CONTRAST-PROFILES_GV_20140224_R1.ict
#     AWAS_Input_File:                 CONTRAST-AWAS_GV_20140224_R0.ict
#     CO_Input_File:                   CONTRAST-CO_GV_20140224_R1.ict
#     CO2CH4_Input_File:               CONTRAST-CO2CH4_GV_20140224_R1.ict
#     DOAS_Input_File:                 CONTRAST-DOAS_GV_20140224_R1.ict
#     GTCIMS_Input_File:               CONTRAST-GTCIMS_GV_20140224_R2.ict
#     HARP_Input_File:                 CONTRAST-HARP_GV_20140224_R1.ict
#     ISAF_Input_File:                 CONTRAST-ISAF_GV_20140224_R0.ict
#     NONO2O3_Input_File:              CONTRAST-NONO2O3_GV_20140224_R3.ict
#     TOGA_Input_File:                 CONTRAST-TOGA_GV_20140224_R2.ict
#     latitude_coordinate:             LATC
#     longitude_coordinate:            LONC
#     zaxis_coordinate:                PSXC
#     geospatial_lat_min:              13.2706
#     geospatial_lat_max:              40.13771
#     geospatial_lon_min:              143.44249
#     geospatial_lon_max:              148.9647
#     geospatial_vertical_min:         129.08089
#     geospatial_vertical_max:         13581.405
#     geospatial_vertical_positive:    up
#     geospatial_vertical_units:       m
#     fill_values:                     -99999.0
#     Categories:                      AWAS,Aircraft_NC,CO,DOAS,GTCIMS,HARP,ISA...
#     landmarks:                       19.746 -155.457 Hawaii,34.481 -118.043 D...

# %%
plt.scatter(contrast_init.GGLON, contrast_init.GGLAT)
