# %%
# script to get and plot TTS for campaign average conditions, varying tau 
# date created: 2/16/2020
# author: sofia chelpon
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
############################ PREP WORKSPACE ############################

# %%
import numpy as np 
import pandas as pd

import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline
# %config inlinebackend.figure_format='retina'

# import my TTS module, need to add path to folder
import sys
sys.path.insert(1, '/Volumes/scdrive2/TTS_2020/base_tts_code/')
import tts_mod

# %%
# read in ratios dataframe
contrast_ratios = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_ratios/contrast_ratios_twp_awas_replace_noRF06.pkl")
ratios_sort = contrast_ratios.sort_values(['TROPO_tau'])
ratios_sort.head()

# utbl, same for all 
utbl = ratios_sort['All RF']

# %%
contrast_ratios
# Out:
#    Instrument                     Trace_Gas        BL_tau     TROPO_tau  \
# 0        AWAS                   C2H6_Ethane     18.996560     51.867565
# 1        AWAS                   C2H2_Ethyne      5.460657      9.761061
# 2        AWAS                  C3H8_Propane      4.276704      9.379963
# 3        AWAS               C4H10_Isobutane      2.193483      4.101641
# 4        AWAS                 C4H10_nButane      1.979710      3.901968
# 5        AWAS                C5H12_nPentane      1.225894      2.360346
# 6        AWAS                  C6H6_Benzene      3.819659      6.602596
# 7        AWAS          OCS_Carbonyl_sulfide   2000.000000   2000.000000
# 8        AWAS        C2H6S_Dimethyl_sulfide      0.655356      0.377066
# 9        AWAS                 CCl2F2_CFC_12  37000.000000  37000.000000
# 10       AWAS                  CCl3F_CFC_11  19000.000000  19000.000000
# 11       AWAS             CCl2FCCl2F_CFC112  22000.000000  22000.000000
# 12       AWAS            CCl3CClF2_CFC_112a  19000.000000  19000.000000
# 13       AWAS               C2Cl3F3_CFC_113  34000.000000  34000.000000
# 14       AWAS               C2Cl2F4_CFC_114  69000.000000  69000.000000
# 15       AWAS                CHClF2_HCFC_22   1100.000000   4500.000000
# 16       AWAS            CH3CClF2_HCFC_142b   1500.000000   5700.000000
# 17       AWAS            CH3CCl2F_HCFC_141b    840.000000   3300.000000
# 18       AWAS              CH2FCF3_HFC_134a   1500.000000   6300.000000
# 19       AWAS              C4H5F5_HFC365mfc   1000.000000   3700.000000
# 20       AWAS         CH3Cl_Methyl_chloride    130.000000    430.000000
# 21       AWAS          CH3Br_Methyl_bromide    160.000000    560.000000
# 22       AWAS     CH2Cl2_Methylene_chloride     46.722142    120.000000
# 23       AWAS              CHCl3_Chloroform     47.889396    120.000000
# 24       AWAS     CH3CCl3_Methyl_chloroform    850.000000   3300.000000
# 25       AWAS     CCl4_Carbon_tetrachloride  12000.000000  12000.000000
# 26       AWAS    C2H4Cl2_1_2_Dichloroethane     19.414215     50.558136
# 27       AWAS     C2Cl4_Tetrachloroethylene     28.154334     83.261722
# 28       AWAS          C6H5Cl_Chlorobenzene      8.023145     10.423557
# 29       AWAS            CBrClF2_Halon_1211   5800.000000   5800.000000
# 30       AWAS            C2Br2F4_Halon_2402  10000.000000  10000.000000
# 31       AWAS    CH2BrCl_Bromochloromethane     46.097435    120.000000
# 32       AWAS      CH2Br2_Methylene_bromide     39.940949    100.000000
# 33       AWAS  CHBrCl2_Bromodichloromethane     27.769025     56.993818
# 34       AWAS  CHBr2Cl_Dibromochloromethane     13.446371     23.997326
# 19  0.927372       NaN  0.978164  0.980636       NaN       NaN   NaN  0.953226
# 20  1.007356       NaN  0.998816  1.015378       NaN       NaN   NaN  0.944566
# 21  1.019186       NaN  0.980378  0.986145       NaN       NaN   NaN  0.953395
# 22  0.795304       NaN  0.890146  0.922755       NaN       NaN   NaN  0.701044
# 23  0.744807       NaN  0.857949  0.914093       NaN       NaN   NaN  0.735788
# 24  0.966959       NaN  0.944649  0.993053       NaN       NaN   NaN  0.972877
# 25  0.987427       NaN  0.979096  1.000762       NaN       NaN   NaN  0.979592
# 26  0.734405       NaN  0.846809  0.822304       NaN       NaN   NaN  0.595943
# 27  0.593507       NaN  0.727384  0.822222       NaN       NaN   NaN  0.648819
# 28  0.433735       NaN  0.436846  0.715441       NaN       NaN   NaN  0.290909
# 29  1.018598       NaN  1.022912  1.022727       NaN       NaN   NaN  1.060773
# 30  0.991870       NaN  0.981581  0.998008       NaN       NaN   NaN  1.000000
# 31  0.826168       NaN  0.795918  1.014493       NaN       NaN   NaN  0.730769
# 32  0.922747       NaN  0.865435  0.958470       NaN       NaN   NaN  0.842783
# 33  0.923044       NaN  1.003067  1.020833       NaN       NaN   NaN  0.677419
# 34  0.927918       NaN  0.941392  0.825086       NaN       NaN   NaN  0.731034
# 35  0.914414       NaN  0.785486  0.751471       NaN       NaN   NaN  0.598291
# 36  1.160691       NaN  0.509115  0.815463       NaN       NaN   NaN  0.716667
# 37  0.374067       NaN  0.468977  0.585465       NaN       NaN   NaN  0.284211
# 38  0.452110       NaN  0.252362  0.507198       NaN       NaN   NaN  0.274227
# 39  0.346964       NaN  0.293575  0.271959       NaN       NaN   NaN  0.072508
# 40  0.212152  0.211208  0.021128  0.254290  0.084959  0.039534   NaN  0.036945
# 41  0.163599  0.455572  1.271104  0.444384  0.020654  0.302145   NaN  0.647687
# 42  0.229809  0.522306  1.227732  0.605284  0.027276  0.339155   NaN  0.784476
# 43  0.373829  0.924865  0.898816  0.776687  0.084024  0.348502   NaN  0.470919
# 44  0.424317  0.895255  1.251672  1.295028  0.128191  0.507453   NaN  0.576389
# 45  0.422359  0.452388  0.292676  0.535780  0.321101  0.380834   NaN  0.336910
# 46  0.856548  1.233019  0.893955  1.046715  0.685594  0.986804   NaN  0.807339
# 47  0.677162  0.885577  0.719536  1.085581  0.443307  0.651159   NaN  0.719434
# 48  0.974084  1.105400  1.020170  1.024895  0.988690  1.122160   NaN  0.831439
# 49  0.816255  0.877338  0.888527  0.904175  0.499802  0.763662   NaN  0.776566
# 50  0.768955  0.939867  0.900389  0.964243  0.588710  0.875519   NaN  0.786058
# 51  0.980102  1.092829  1.016046  1.241072  1.027174  1.030493   NaN  0.983135

# %%
############################ GET TTS OUTPUTS FOR EA. CASE ############################

# %%
# --------------- ver 1: BL TAU 
tau_bl = ratios_sort['BL_tau'].values

# get inputs
t_bl, exp_decay_matrix_bl, LT_bl = tts_mod.prep_for_tts(tau_bl)
# get tts 
my_mustar_bl, my_r2_bl, my_gf_bl, my_t_bl, mean_age_bl, \
    mode_age_bl, best_k_bl = tts_mod.get_tts(utbl, tau_bl, t_bl, exp_decay_matrix_bl, LT_bl)
print(best_k_bl)
# Out:
# 177

# %%
# save campaign average for later use 
campaign_avg_figa = pd.DataFrame()
campaign_avg_figa['tau'] = tau_bl
campaign_avg_figa['utbl'] = utbl.values
campaign_avg_figa['mustar'] = my_mustar_bl

campaign_avg_figb = pd.DataFrame()
campaign_avg_figb['t'] = t_bl/86400
campaign_avg_figb['gf'] = my_gf_bl

campaign_avg_stats = pd.DataFrame({'r squared': [my_r2_bl], 'mean age': [mean_age_bl], 'mode age': [mode_age_bl]})

campaign_avg_figa.to_pickle('./campaign_avg_figa_noRF06.pkl')
campaign_avg_figb.to_pickle('./campaign_avg_figb_noRF06.pkl')
campaign_avg_stats.to_pickle('./campaign_avg_stats_noRF06.pkl')

# %%
# --------------- ver 2: BL TROPO
tau_tr = ratios_sort['TROPO_tau'].values

# get inputs
t_tr, exp_decay_matrix_tr, LT_tr = tts_mod.prep_for_tts(tau_tr)
# get tts 
my_mustar_tr, my_r2_tr, my_gf_tr, my_t_tr, mean_age_tr, \
    mode_age_tr, best_k_tr = tts_mod.get_tts(utbl, tau_tr, t_tr, exp_decay_matrix_tr, LT_tr)
print(best_k_tr)
# Out:
# 105

# %%
# --------------- ver 2: BL UT
tau_ut = ratios_sort['UT_tau'].values

# get inputs
t_ut, exp_decay_matrix_ut, LT_ut = tts_mod.prep_for_tts(tau_ut)
# get tts 
my_mustar_ut, my_r2_ut, my_gf_ut, my_t_ut, mean_age_ut, \
    mode_age_ut, best_k_ut = tts_mod.get_tts(utbl, tau_ut, t_ut, exp_decay_matrix_ut, LT_ut)
print(best_k_ut)
# Out:
# 64

# %%
############################ PLOT TTS OUTPUTS FOR EA. CASE ############################
# import my TTS module, need to add path to folder
import imp
imp.reload(tts_mod)
# Out:
# <module 'tts_mod' from '/Volumes/scdrive2/TTS_2020/base_tts_code/tts_mod.py'>

# %%
# --------------- start plot with BL case
title_str = r'$\tau_{BL}$: '
my_color = 'k'
overplot = 0
add_scatter = 1
add_r2 = 1 
add_meanmode = 1
# first plot only, dummies (will get real after first run creates fig)
width = 0
height = 0
my_ax = 0

fig, my_ax, width, height = tts_mod.plot_tts(tau_bl, my_mustar_bl, utbl, my_r2_bl, my_gf_bl, 
                                        my_t_bl, mean_age_bl, mode_age_bl, 
                                        my_color, overplot, add_scatter, add_r2, 
                                        add_meanmode, my_ax, width, height, title_str)

# --------------- add TROPO case 
title_str = r'$\tau_{tropo}$: '
my_color = [0.83, 0.13, 0.18]
overplot = 1
add_scatter = 1
add_r2 = 1 
add_meanmode = 1

tts_mod.plot_tts(tau_tr, my_mustar_tr, utbl, my_r2_tr, my_gf_tr, 
                                        my_t_tr, mean_age_tr, mode_age_tr, 
                                        my_color, overplot, add_scatter, add_r2, 
                                        add_meanmode, my_ax, width, height, title_str)

# --------------- add UT case 
title_str = r'$\tau_{UT}$: '
my_color = [0, 0.09, 0.66] #pantone blue
overplot = 2
add_scatter = 1
add_r2 = 1 
add_meanmode = 1

tts_mod.plot_tts(tau_ut, my_mustar_ut, utbl, my_r2_ut, my_gf_ut, 
                                        my_t_ut, mean_age_ut, mode_age_ut, 
                                        my_color, overplot, add_scatter, add_r2, 
                                        add_meanmode, my_ax, width, height, title_str)

# --------------- save figure 
fig.savefig('./tts_vary_tau_twp_noRF06.pdf')  
#fig.savefig(svpath + 'tts_vary_tau.svg')
