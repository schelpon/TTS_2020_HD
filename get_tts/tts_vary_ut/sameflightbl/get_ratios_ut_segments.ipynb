# %%
# get ratios for segment analysis 
# use BL of whole campaign 
# date created: 3/2/2020
# author: sofia chelpon

# %%
import numpy as np 
import xarray as xr
import pandas as pd 
import datetime 
import seaborn as sns

import datetime as dt 

import matplotlib
from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
from mpl_toolkits import mplot3d

# %matplotlib inline
# %config inlinebackend.figure_format='retina'

# %%
#### ------------------- LOAD IN 
# data overall 
awas_df = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_ratios/awas_data_df.pkl")
toga_df = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_ratios/toga_data_df.pkl")

# segment data
awas_segments = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_tts/tts_vary_ut/data_prep/awas_segments.pkl")
awas_segments = awas_segments.drop(columns = 'GGALT').drop(columns = 'GGLAT').drop(columns ='GGLON').drop(columns = 'Notes')
# segment data 
toga_segments = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_tts/tts_vary_ut/data_prep/toga_segments.pkl")
toga_segments = toga_segments.drop(columns = 'GGALT').drop(columns = 'GGLAT').drop(columns ='GGLON')

# %%
##### --------------------- get campaign average BL means per RF 
# AWAS 
awas_means = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_ratios/awas_means.pkl")
awas_means = awas_means.drop(columns = 'UT - All RF').drop(columns = 'BL - All RF')
awas_means = awas_means.drop(columns = 'UT - RF03').drop(columns = 'UT - RF04').drop(columns = 'UT - RF05')
awas_means = awas_means.drop(columns = 'UT - RF06').drop(columns = 'UT - RF07').drop(columns = 'UT - RF08')
awas_means = awas_means.drop(columns = 'UT - RF09').drop(columns = 'UT - RF10').drop(columns = 'UT - RF11')
awas_means = awas_means.drop(columns = 'UT - RF12').drop(columns = 'UT - RF13').drop(columns = 'UT - RF14')
awas_means 


awas_bl
# Out:
# Trace_Gas
# C2H6_Ethane                    NaN
# C2H2_Ethyne                    NaN
# C3H8_Propane                   NaN
# C4H10_Isobutane                NaN
# C4H10_nButane                  NaN
# C5H12_nPentane                 NaN
# C6H6_Benzene                   NaN
# OCS_Carbonyl_sulfide           NaN
# C2H6S_Dimethyl_sulfide         NaN
# CCl2F2_CFC_12                  NaN
# CCl3F_CFC_11                   NaN
# CCl2FCCl2F_CFC112              NaN
# CCl3CClF2_CFC_112a             NaN
# C2Cl3F3_CFC_113                NaN
# C2Cl2F4_CFC_114                NaN
# CHClF2_HCFC_22                 NaN
# CH3CClF2_HCFC_142b             NaN
# CH3CCl2F_HCFC_141b             NaN
# CH2FCF3_HFC_134a               NaN
# C4H5F5_HFC365mfc               NaN
# CH3Cl_Methyl_chloride          NaN
# CH3Br_Methyl_bromide           NaN
# CH2Cl2_Methylene_chloride      NaN
# CHCl3_Chloroform               NaN
# CH3CCl3_Methyl_chloroform      NaN
# CCl4_Carbon_tetrachloride      NaN
# C2H4Cl2_1_2_Dichloroethane     NaN
# C2Cl4_Tetrachloroethylene      NaN
# C6H5Cl_Chlorobenzene           NaN
# CBrClF2_Halon_1211             NaN
# C2Br2F4_Halon_2402             NaN
# CH2BrCl_Bromochloromethane     NaN
# CH2Br2_Methylene_bromide       NaN
# CHBrCl2_Bromodichloromethane   NaN
# CHBr2Cl_Dibromochloromethane   NaN
# CHBr3_Bromoform                NaN
# C2H5ONO2_Ethyl_nitrate         NaN
# C3H7NO3_Isopropyl_nitrate      NaN
# C4H9NO3_2_Butyl_nitrate        NaN
# C4H9NO3_n_Butyl_nitrate        NaN
# Name: BL - RF14, dtype: float64

# %%
# ##### --------------------- get campaign average BL means per RF 
# toga 
toga_means = pd.read_pickle("/Volumes/scdrive2/TTS_2020/get_ratios/toga_means.pkl")
toga_means = toga_means.drop(columns = 'UT - All RF').drop(columns = 'BL - All RF')
toga_means = toga_means.drop(columns = 'UT - RF03').drop(columns = 'UT - RF04').drop(columns = 'UT - RF05')
toga_means = toga_means.drop(columns = 'UT - RF06').drop(columns = 'UT - RF07').drop(columns = 'UT - RF08')
toga_means = toga_means.drop(columns = 'UT - RF09').drop(columns = 'UT - RF10').drop(columns = 'UT - RF11')
toga_means = toga_means.drop(columns = 'UT - RF12').drop(columns = 'UT - RF13').drop(columns = 'UT - RF14')
toga_means = toga_means.set_index('Trace_Gas')
toga_means
# Out:
#                        BL - RF03   BL - RF04   BL - RF05   BL - RF06  \
# Trace_Gas
# Acetaldehyde          167.108337  229.972427  138.208313  243.136383
# n_Butane                4.257334   16.403793   19.059166   95.634613
# i_Butane                2.712333   11.994135   13.337778   56.692314
# Benzene                12.359667   34.138618   22.677223   75.059166
# C3H8                   27.666666  108.724136  103.805557  336.076935
# Methanol              477.250000  810.896545  616.972229  452.500000
# Bromoform               0.841533    1.074793    1.005944    1.256000
# Tetrachloroethylene     1.404000    1.759310    1.360278    2.660833
# Dibromomethane          1.015167    1.058965    1.044278    1.230500
# Dichloromethane        53.164658   72.776207   50.533333   71.598465
# Chloroform             10.440000   13.292414   10.087779   14.672308
# Carbon_Tetrachloride   87.720009   84.700005   90.955544   88.830765
#
#                        BL - RF07   BL - RF08   BL - RF09   BL - RF10  \
# Trace_Gas
# Acetaldehyde          234.776627  176.543213  183.899994  139.983322
# n_Butane               12.685163   14.700541    6.035000    3.282308
# i_Butane                9.587420    9.929460    5.305000    2.773846
# Benzene                25.335808   21.052973   12.070000   12.736923
# C3H8                  101.870964   78.459457   36.000000   33.346153
# Methanol              751.774170  541.108093  663.000000  676.884644
# Bromoform               1.103645    0.900757    0.730000    0.824615
# Tetrachloroethylene     1.712581    1.543514    1.300000    1.325000
# Dibromomethane          1.092871    1.086405    1.055500    1.074692
# Dichloromethane        58.369995   52.140541   49.004997   50.875381
# Chloroform             11.723871   11.089731    9.770000    9.801924
# Carbon_Tetrachloride   86.912903   90.135132   83.150002   86.626915
#
#                        BL - RF11   BL - RF12   BL - RF13  BL - RF14
# Trace_Gas
# Acetaldehyde          249.972717  447.666656  279.600006        NaN
# n_Butane                4.648181   28.183334   12.250000        NaN
# i_Butane                3.678182   24.086664    9.280000        NaN
# Benzene                16.302727   66.946663   25.750000        NaN
# C3H8                   26.090910  177.333328   95.000000        NaN
# Methanol              619.909119  912.666687  705.000000        NaN
# Bromoform               0.588636    1.080000    0.682000        NaN
# Tetrachloroethylene     1.013636    2.090000    1.570000        NaN
# Dibromomethane          0.980889    1.048333    0.915000        NaN
# Dichloromethane        55.081249   82.116669   56.169998        NaN
# Chloroform              9.630909   13.963333    9.890000        NaN
# Carbon_Tetrachloride   69.590912   81.899994   82.300003        NaN

# %%
######## ------------- GET AWAS RATIOS 
# thing to fill with ratios 
awas_seg_ratios = pd.DataFrame()
for col in awas_df.columns: 
    awas_seg_ratios[col] = ''
awas_seg_ratios = awas_seg_ratios.drop(columns = 'GGALT').drop(columns = 'GGLAT').drop(columns = 'GGLON').drop(columns = 'Notes').drop(columns = 'Intrument')
    
# loop through every segment and get ratio for it 
for idx in (np.arange(0, len(awas_segments))):
    # find segment, get info 
    awas_ut = awas_segments.iloc[idx]
    idx_info = pd.Series({'Time_UTC': awas_ut['Time_UTC'], 'Flight': awas_ut['Flight']})
    thisfl = idx_info['Flight']
    flstr = 'BL - ' + thisfl
    # get ratio 
    awas_ut = awas_ut.drop('Time_UTC').drop('Intrument').drop('Flight')
    awas_bl = awas_means[flstr]
    idx_rat = awas_ut/awas_bl
    # merge to info 
    to_append = idx_info.append(idx_rat)
    to_append = pd.DataFrame(to_append).transpose()
    # append
    awas_seg_ratios = awas_seg_ratios.append(to_append, ignore_index = True)

# %%
######## ------------- GET TOGA RATIOS 
# thing to fill with ratios 
toga_seg_ratios = pd.DataFrame()
for col in toga_df.columns: 
    toga_seg_ratios[col] = ''
toga_seg_ratios = toga_seg_ratios.drop(columns = 'GGALT').drop(columns = 'GGLAT').drop(columns = 'GGLON').drop(columns = 'Notes').drop(columns = 'Intrument')
    
# loop through every segment and get ratio for it 
for idx in (np.arange(0, len(toga_segments))):
    # find segment, get info 
    toga_ut = toga_segments.iloc[idx]
    idx_info = pd.Series({'Time_UTC': toga_ut['Time_UTC'], 'Flight': toga_ut['Flight']})
    thisfl = idx_info['Flight']
    flstr = 'BL - ' + thisfl
    # get ratio 
    toga_ut = toga_ut.drop('Time_UTC').drop('Intrument').drop('Flight')
    toga_bl = toga_means[flstr]
    idx_rat = toga_ut/toga_bl
    # merge to info 
    to_append = idx_info.append(idx_rat)
    to_append = pd.DataFrame(to_append).transpose()
    # append
    toga_seg_ratios = toga_seg_ratios.append(to_append, ignore_index = True)

# %%
### add attribute to each species (BL, tropo, and UT lifetimes)
fill = pd.DataFrame([[np.nan, np.nan, np.nan, np.nan]], columns=['Trace_Gas', 'BL_tau', 'TROPO_tau', 'UT_tau'])
fill = fill.append(fill)

# --------- AWAS 
# read in from xls file to make dataframe - awas
mypath2 = '/Volumes/scdrive2/TTS_2020/contrast_readin/awas/awas_lifetimes_12162019.xlsx'
awas_lifetimes = pd.read_excel(mypath2)
awas_lifetimes = fill.append(awas_lifetimes)
awas_lifetimes = awas_lifetimes.reset_index().drop('index', axis = 1)

# --------- TOGA
# read in from xls file to make dataframe - toga 
mypath2 = '/Volumes/scdrive2/TTS_2020/contrast_readin/toga_lodhalf/toga_lifetimes_12162019.xlsx'
toga_lifetimes = pd.read_excel(mypath2)
toga_lifetimes = fill.append(toga_lifetimes)
toga_lifetimes = toga_lifetimes.reset_index().drop('index', axis = 1)

# %%
# combine data from both instruments to one dataframe 
# --------- AWAS 
awas_seg_ratios = awas_seg_ratios.transpose()
awas_seg_ratios.insert(0, 'Instrument', 'AWAS')

# add lifetimes 
awas_seg_ratios.insert(1, 'BL_tau', awas_lifetimes['BL_tau'].values)
awas_seg_ratios.insert(2, 'TROPO_tau', awas_lifetimes['TROPO_tau'].values)
awas_seg_ratios.insert(3, 'UT_tau', awas_lifetimes['UT_tau'].values)

# --------- TOGA 
toga_seg_ratios = toga_seg_ratios.transpose()
toga_seg_ratios.insert(0, 'Instrument', 'TOGA')

# add lifetimes 
toga_seg_ratios.insert(1, 'BL_tau', toga_lifetimes['BL_tau'].values)
toga_seg_ratios.insert(2, 'TROPO_tau', toga_lifetimes['TROPO_tau'].values)
toga_seg_ratios.insert(3, 'UT_tau', toga_lifetimes['UT_tau'].values)

# %%
# combine data from both instruments to one dataframe 
toga_seg_ratios = toga_seg_ratios.drop('Time_UTC', axis = 0)
toga_seg_ratios = toga_seg_ratios.drop('Flight', axis = 0)

ratios_comb = awas_seg_ratios.append(toga_seg_ratios)
ratios_comb
# Out:
#                              Instrument        BL_tau     TROPO_tau  \
# Time_UTC                           AWAS           NaN           NaN
# Flight                             AWAS           NaN           NaN
# C2H6_Ethane                        AWAS     18.555721     48.949092
# C2H2_Ethyne                        AWAS      5.422335      9.603369
# C3H8_Propane                       AWAS      4.214557      9.062693
# C4H10_Isobutane                    AWAS      2.175570      4.031311
# C4H10_nButane                      AWAS      1.959376      3.813463
# C5H12_nPentane                     AWAS      1.214449      2.312606
# C6H6_Benzene                       AWAS      3.755136      6.447323
# OCS_Carbonyl_sulfide               AWAS   2000.000000   2000.000000
# C2H6S_Dimethyl_sulfide             AWAS      0.955122      1.689426
# CCl2F2_CFC_12                      AWAS  37000.000000  37000.000000
# CCl3F_CFC_11                       AWAS  19000.000000  19000.000000
# CCl2FCCl2F_CFC112                  AWAS  22000.000000  22000.000000
# CCl3CClF2_CFC_112a                 AWAS  19000.000000  19000.000000
# C2Cl3F3_CFC_113                    AWAS  34000.000000  34000.000000
# C2Cl2F4_CFC_114                    AWAS  69000.000000  69000.000000
# CHClF2_HCFC_22                     AWAS    985.207857   3404.616878
# CH3CClF2_HCFC_142b                 AWAS   1481.167218   5652.463359
# CH3CCl2F_HCFC_141b                 AWAS    815.151719   2960.318425
# CH2FCF3_HFC_134a                   AWAS   1085.569271   4041.209884
# C4H5F5_HFC365mfc                   AWAS    810.126321   3015.828272
# CH3Cl_Methyl_chloride              AWAS    126.022560    394.362305
# CH3Br_Methyl_bromide               AWAS    159.201226    515.730757
# CH2Cl2_Methylene_chloride          AWAS     45.867749    109.800998
# CHCl3_Chloroform                   AWAS     52.944984    131.597555
# CH3CCl3_Methyl_chloroform          AWAS    466.016381   1571.229062
# CCl4_Carbon_tetrachloride          AWAS  12000.000000  12000.000000
# C2H4Cl2_1_2_Dichloroethane         AWAS     18.999939     47.956206
# C2Cl4_Tetrachloroethylene          AWAS     27.471720     77.860538
# C6H5Cl_Chlorobenzene               AWAS      6.247813     11.592622
# CBrClF2_Halon_1211                 AWAS   5800.000000   5800.000000
# C2Br2F4_Halon_2402                 AWAS  10000.000000  10000.000000
# CH2BrCl_Bromochloromethane         AWAS     45.186536    111.992317
# C2H6_Ethane                              0.470512  ...                  NaN
# C2H2_Ethyne                              0.279843  ...                  NaN
# C3H8_Propane                             0.146527  ...                  NaN
# C4H10_Isobutane                         0.0933711  ...                  NaN
# C4H10_nButane                            0.104924  ...                  NaN
# C5H12_nPentane                          0.0161002  ...                  NaN
# C6H6_Benzene                             0.162362  ...                  NaN
# OCS_Carbonyl_sulfide                     0.986268  ...                  NaN
# C2H6S_Dimethyl_sulfide                        NaN  ...                  NaN
# CCl2F2_CFC_12                            0.998587  ...                  NaN
# CCl3F_CFC_11                             0.976636  ...                  NaN
# CCl2FCCl2F_CFC112                        0.971253  ...                  NaN
# CCl3CClF2_CFC_112a                       0.804598  ...                  NaN
# C2Cl3F3_CFC_113                          0.976509  ...                  NaN
# C2Cl2F4_CFC_114                           0.97792  ...                  NaN
# CHClF2_HCFC_22                           0.957464  ...                  NaN
# CH3CClF2_HCFC_142b                        1.00419  ...                  NaN
# CH3CCl2F_HCFC_141b                       0.941795  ...                  NaN
# CH2FCF3_HFC_134a                         0.962784  ...                  NaN
# C4H5F5_HFC365mfc                         0.859234  ...                  NaN
# CH3Cl_Methyl_chloride                    0.950048  ...                  NaN
# CH3Br_Methyl_bromide                     0.925806  ...                  NaN
# CH2Cl2_Methylene_chloride                0.641201  ...                  NaN
# CHCl3_Chloroform                          0.66977  ...                  NaN
# CH3CCl3_Methyl_chloroform                0.976143  ...                  NaN
# CCl4_Carbon_tetrachloride                0.978391  ...                  NaN
# C2H4Cl2_1_2_Dichloroethane               0.522838  ...                  NaN
# C2Cl4_Tetrachloroethylene                0.526907  ...                  NaN
# C6H5Cl_Chlorobenzene                     0.470169  ...                  NaN
# CBrClF2_Halon_1211                        1.06747  ...                  NaN
# C2Br2F4_Halon_2402                       0.973236  ...                  NaN
# CH2BrCl_Bromochloromethane               0.885057  ...                  NaN
# CH2Br2_Methylene_bromide                 0.871663  ...                  NaN
# CHBrCl2_Bromodichloromethane              1.88889  ...                  NaN
# CHBr2Cl_Dibromochloromethane             0.976834  ...                  NaN
# CHBr3_Bromoform                          0.712303  ...                  NaN
# C2H5ONO2_Ethyl_nitrate                   0.887881  ...                  NaN
# C3H7NO3_Isopropyl_nitrate                0.326836  ...                  NaN
# C4H9NO3_2_Butyl_nitrate                  0.368779  ...                  NaN
# C4H9NO3_n_Butyl_nitrate                 0.0656148  ...                  NaN
# Acetaldehyde                            0.0180886  ...           0.00894134
# n_Butane                                 0.207949  ...             0.342041
# i_Butane                                 0.282906  ...             0.362787
# Benzene                                  0.313677  ...             0.358964
# C3H8                                     0.414236  ...             0.494737
# Methanol                                 0.246905  ...              0.32766
# Bromoform                                0.575579  ...             0.990225
# Tetrachloroethylene                      0.700837  ...             0.707006
# Dibromomethane                            1.08177  ...               1.1694
# Dichloromethane                          0.795053  ...              0.78749
# Chloroform                               0.807247  ...             0.858443
# Carbon_Tetrachloride                     0.980699  ...             0.993115
#
#                                               165                  166  \
# Time_UTC                      2014-02-22 00:37:11  2014-02-22 00:47:12
# Flight                                       RF14                 RF14
# C2H6_Ethane                                   NaN                  NaN
# C2H2_Ethyne                                   NaN                  NaN
# C3H8_Propane                                  NaN                  NaN
# CH2Br2_Methylene_bromide                      NaN                  NaN
# CHBrCl2_Bromodichloromethane                  NaN                  NaN
# CHBr2Cl_Dibromochloromethane                  NaN                  NaN
# CHBr3_Bromoform                               NaN                  NaN
# C2H5ONO2_Ethyl_nitrate                        NaN                  NaN
# C3H7NO3_Isopropyl_nitrate                     NaN                  NaN
# C4H9NO3_2_Butyl_nitrate                       NaN                  NaN
# C4H9NO3_n_Butyl_nitrate                       NaN                  NaN
# Acetaldehyde                                  NaN                  NaN
# n_Butane                                      NaN                  NaN
# i_Butane                                      NaN                  NaN
# Benzene                                       NaN                  NaN
# C3H8                                          NaN                  NaN
# Methanol                                      NaN                  NaN
# Bromoform                                     NaN                  NaN
# Tetrachloroethylene                           NaN                  NaN
# Dibromomethane                                NaN                  NaN
# Dichloromethane                               NaN                  NaN
# Chloroform                                    NaN                  NaN
# Carbon_Tetrachloride                          NaN                  NaN
#
#                                               173
# Time_UTC                      2014-02-22 01:51:44
# Flight                                       RF14
# C2H6_Ethane                                   NaN
# C2H2_Ethyne                                   NaN
# C3H8_Propane                                  NaN
# C4H10_Isobutane                               NaN
# C4H10_nButane                                 NaN
# C5H12_nPentane                                NaN
# C6H6_Benzene                                  NaN
# OCS_Carbonyl_sulfide                          NaN
# C2H6S_Dimethyl_sulfide                        NaN
# CCl2F2_CFC_12                                 NaN
# CCl3F_CFC_11                                  NaN
# CCl2FCCl2F_CFC112                             NaN
# CCl3CClF2_CFC_112a                            NaN
# C2Cl3F3_CFC_113                               NaN
# C2Cl2F4_CFC_114                               NaN
# CHClF2_HCFC_22                                NaN
# CH3CClF2_HCFC_142b                            NaN
# CH3CCl2F_HCFC_141b                            NaN
# CH2FCF3_HFC_134a                              NaN
# C4H5F5_HFC365mfc                              NaN
# CH3Cl_Methyl_chloride                         NaN
# CH3Br_Methyl_bromide                          NaN
# CH2Cl2_Methylene_chloride                     NaN
# CHCl3_Chloroform                              NaN
# CH3CCl3_Methyl_chloroform                     NaN
# CCl4_Carbon_tetrachloride                     NaN
# C2H4Cl2_1_2_Dichloroethane                    NaN
# C2Cl4_Tetrachloroethylene                     NaN
# C6H5Cl_Chlorobenzene                          NaN
# CBrClF2_Halon_1211                            NaN
# C2Br2F4_Halon_2402                            NaN
# CH2BrCl_Bromochloromethane                    NaN
# CH2Br2_Methylene_bromide                      NaN
# CHBrCl2_Bromodichloromethane                  NaN
# CHBr2Cl_Dibromochloromethane                  NaN
# CHBr3_Bromoform                               NaN
# C2H5ONO2_Ethyl_nitrate                        NaN
# C3H7NO3_Isopropyl_nitrate                     NaN
# C4H9NO3_2_Butyl_nitrate                       NaN
# C4H9NO3_n_Butyl_nitrate                       NaN
# Acetaldehyde                                  NaN
# n_Butane                                      NaN
# i_Butane                                      NaN
# Benzene                                       NaN
# C3H8                                          NaN
# Methanol                                      NaN
# Bromoform                                     NaN
# Tetrachloroethylene                           NaN
# Dibromomethane                                NaN
# Dichloromethane                               NaN
# Chloroform                                    NaN
# Carbon_Tetrachloride                          NaN
#
# [54 rows x 178 columns]

# %%
# pickle this!! 
ratios_comb.to_pickle("./contrast_ratios_ut_seg_sameflightbl.pkl")
